# %% [markdown]
# <a href="https://colab.research.google.com/github/SiYeon-Ju/Colab_work/blob/main/Cobrapy_OB3b_220629_work_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version ## 3.7 버전에서 구동 확인 ##
# !pip install cobra==0.17.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cobra==0.17.0
#   Downloading cobra-0.17.0-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.2 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from cobra==0.17.0) (0.16.0)
# Collecting optlang>=1.4.2
#   Downloading optlang-1.5.2-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 33.7 MB/s
# Collecting ruamel.yaml>=0.16
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 47.9 MB/s
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.7/dist-packages (from cobra==0.17.0) (1.21.6)
# Collecting swiglpk
#   Downloading swiglpk-5.0.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 37.6 MB/s
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from cobra==0.17.0) (1.3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cobra==0.17.0) (1.15.0)
# Collecting depinfo
#   Downloading depinfo-2.1.1-py3-none-any.whl (23 kB)
# Collecting python-libsbml-experimental==5.18.0
#   Downloading python_libsbml_experimental-5.18.0-cp37-cp37m-manylinux1_x86_64.whl (43.9 MB)
#      |████████████████████████████████| 43.9 MB 1.6 MB/s
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang>=1.4.2->cobra==0.17.0) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->cobra==0.17.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->cobra==0.17.0) (2022.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 14.8 MB/s
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang>=1.4.2->cobra==0.17.0) (1.2.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from depinfo->cobra==0.17.0) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->depinfo->cobra==0.17.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->depinfo->cobra==0.17.0) (4.1.1)
# Installing collected packages: swiglpk, ruamel.yaml.clib, ruamel.yaml, python-libsbml-experimental, optlang, depinfo, cobra
# Successfully installed cobra-0.17.0 depinfo-2.1.1 optlang-1.5.2 python-libsbml-experimental-5.18.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 swiglpk-5.0.5

# %%
# !git clone https://github.com/ensakz/gem_methylosinus_trichosporium.git
# Out:
# Cloning into 'gem_methylosinus_trichosporium'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 68 (delta 13), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
### Cobrapy # 0.17.0 버전 Doc
### https://cobrapy.readthedocs.io/en/0.17.1/configuration.html
#### Cobrapy # latest 버전 Doc
### https://cobrapy.readthedocs.io/en/latest/index.html


### 라이브러리 불러오기 ###
import cobra
import pandas as pd
import numpy as np

### 함수 추가 ###

## 모델 정보 저장 ##
# id, reaction, name, lower_bound, upper_bound, gene_reaction_rule #
def model_info(model): 
  lst = []
  for i in range(len(model.reactions)):
    lst.append([model.reactions[i].id, model.reactions[i].reaction, model.reactions[i].name, 
    model.reactions[i].lower_bound, model.reactions[i].upper_bound,  model.reactions[i].gene_reaction_rule])
  global info 
  info = pd.DataFrame( lst, columns = ['ID', 'Rxn', 'Gene_name', 'LB','UB','Gene_Rxn_Rule'] )
  info.to_csv(str(model) + '_Model_info.csv', header = True)
  return print('Model_info save complete!')

## 모델 정보 + Flux 저장 ##
def model_flux(model, sol): 
  lst = []
  for i in range(len(model.reactions)):
    lst.append([model.reactions[i].id, model.reactions[i].reaction, model.reactions[i].name, 
    model.reactions[i].lower_bound, model.reactions[i].upper_bound,  model.reactions[i].gene_reaction_rule])
  global info 
  info = pd.DataFrame( lst, columns = ['ID', 'Rxn', 'Gene_name', 'LB','UB','Gene_Rxn_Rule'] )
  global flux
  flux_data = pd.DataFrame([sol.fluxes.index, sol.fluxes], index = ['ID', 'Flux']).transpose()
  Merging_data = pd.merge(info, flux_data, on ='ID')
  flux = Merging_data[['ID', 'Rxn', 'Flux','LB', 'UB', 'Gene_Rxn_Rule', 'Gene_name']]
  flux.to_csv(str(model)+'_'+ str(sol) +'_Flux_results.csv', header = True)
  return print('Model_flux save complete!')

# %%
## Json 모델 불러오기 ##
model_dir = r'/content/gem_methylosinus_trichosporium/model_files/iMsOB3b.json'
iMsOB3b = cobra.io.load_json_model(model_dir)

from cobra import Model, Reaction, Metabolite
reaction = Reaction('PBHB_EX')  
reaction.name = 'PBHB_EX'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default
iMsOB3b.add_reaction(reaction)
iMsOB3b.reactions.PBHB_EX.reaction = 'pbhb_c => '  # PHAS에 CoA가 반응식에서 나오기에, 이런 걸로 따로 빼줘야만함 
### 안빼주면 CoA가 붙는 Reaction 때문에 값이 이상하게 나와.. 실제로 0이 나옴... ###


# Bound 설정 #
iMsOB3b.reactions.EX_ch4_e.bounds = (-14.9, 0)  #### 이성근님이 이걸 그냥 -100으로 해서 계산하라고 하심
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)

# FBA 축약본 보기 #
iMsOB3b.summary()
   
# 모델 정보 저장 ('info'로 flux확인 가능)   
model_info(iMsOB3b)
# Out:
# Model_info save complete!

# %%
## 모델에 새 반응식 추가하는 방법..##
# iMsOB3b_v2 = cobra.io.load_json_model(model_dir)
# JSY = iMsOB3b_v2.reactions.PHAS
# JSY.id = 'JSY'
# JSY.reaction = "ch4_p + o2_p + qh2_c --> h2o_p + meoh_p + q_c"
# iMsOB3b.add_reaction(JSY)
# model_info(iMsOB3b)


## 아애 반응식 지우는법 ##
# iMsOB3b.reactions.JSY.remove_from_model()
# model_info(iMsOB3b)
# Out:
# Model_info save complete!

# %%
## 모델의 Bounds 설정 ##
iMsOB3b.reactions.EX_ch4_e.bounds = (-14.9, 0)  ## 메탄 uptake rates
iMsOB3b.reactions.FALDA.bounds = (0, 0)         ## THF 관련 유전자
iMsOB3b.reactions.EX_nh4_e.bounds = (0, 0)      ## 암모니아 바운드 0
iMsOB3b.reactions.EX_n2_e.bounds = (0, 0)       ## 질소 바운드 0
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)  ## 질산 바운드 -inf ## 과제팀은 이거씀

iMsOB3b.reactions.PHBD2.bounds = (0, 0) ## pbhb_c 분해 경로 제거

iMsOB3b.reactions.Biomass_Mextorquens_AM1_core.bounds = (0, 0) ## Biomass 0

## objective function 변경 및 확인 ##
iMsOB3b.objective = 'PBHB_EX'
print('print objective:', iMsOB3b.objective.expression)

## FBA 축약본 보기 ##
iMsOB3b.summary()

####### FBA analysis #########
FBA_sol = iMsOB3b.optimize()
FBA_sol.fluxes.to_csv('FBA_result.json')
#solution.fluxes
print(FBA_sol.fluxes.PBHB_EX)
## pFBA flux값 저장 ###
model_flux(iMsOB3b, FBA_sol) #### 함수 model_flux에  Model과 Sol 넣으면 저장됨 ###
# Out:
# print objective: 1.0*PBHB_EX - 1.0*PBHB_EX_reverse_270b0
# 1.6555555555555557
# Model_flux save complete!

# %%
################## Methan을 -100으로 bound 설정 ##################
##################################################################
######################################################################
## 모델의 Bounds 설정 ##
iMsOB3b.reactions.EX_ch4_e.bounds = (-100, 0)  ## 메탄 uptake rates
iMsOB3b.reactions.FALDA.bounds = (0, 0)         ## THF 관련 유전자
iMsOB3b.reactions.EX_nh4_e.bounds = (0, 0)      ## 암모니아 바운드 0
iMsOB3b.reactions.EX_n2_e.bounds = (0, 0)       ## 질소 바운드 0
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)  ## 질산 바운드 -inf ## 과제팀은 이거씀

iMsOB3b.reactions.PHBD2.bounds = (0, 0) ## pbhb_c 분해 경로 제거

iMsOB3b.reactions.Biomass_Mextorquens_AM1_core.bounds = (0, 0) ## Biomass 0

## objective function 변경 및 확인 ##
iMsOB3b.objective = 'PBHB_EX'
print('print objective:', iMsOB3b.objective.expression)

## FBA 축약본 보기 ##
iMsOB3b.summary()

####### FBA analysis #########
FBA_sol = iMsOB3b.optimize()
FBA_sol.fluxes.to_csv('FBA_result.json')
#solution.fluxes
print(FBA_sol.fluxes.PBHB_EX)
## pFBA flux값 저장 ###
model_flux(iMsOB3b, FBA_sol) #### 함수 model_flux에  Model과 Sol 넣으면 저장됨 ###
# Out:
# print objective: 1.0*PBHB_EX - 1.0*PBHB_EX_reverse_270b0
# 11.111111111111114
# Model_flux save complete!

# %%
## Parsimonas FBA 분석 ##
pFBA_sol_ = cobra.flux_analysis.pfba(iMsOB3b,objective = 'PHAS')

## pFBA flux값 저장 ###
model_flux(iMsOB3b, pFBA_sol_)

## FBA와 pFBA간에 차이 확인 ##
print('FBA - pFBA',abs(FBA_sol.fluxes["PHAS"] - pFBA_sol_.fluxes["PHAS"]))
pFBA_sol_.fluxes.to_csv('pFBA_result.json')
# Out:
# Model_flux save complete!
# FBA - pFBA 3.552713678800501e-15

# %%
## Loopless FBA 분석 ##
#### 아래건 이상하게 안돌아간다...####
# from cobra.flux_analysis.loopless import add_loopless, loopless_solution
# print('start')
# with iMsOB3b:
#     add_loopless(iMsOB3b)
#     try:
#         print(iMsOB3b.solver)
#         solution = iMsOB3b.optimize()
#     except:
#         print('model is infeasible')
# print("loopless solution: status = " + solution.status)
# print("loopless solution flux: v3 = %.1f" % solution.fluxes["v3"])

## If there is no forced flux through a loopless reaction, parsimonious FBA will also have no flux through the loop.
## ref) https://cobrapy.readthedocs.io/en/latest/loopless.html#Loopless-model
# Out:
# start

# %%
## Loopless FBA 분석_v2 이건 돌아간다? ##
from cobra.flux_analysis.loopless import add_loopless, loopless_solution


######################################################################
model_dir = r'/content/gem_methylosinus_trichosporium/model_files/iMsOB3b.json'
iMsOB3b = cobra.io.load_json_model(model_dir)

add_loopless(iMsOB3b)
from cobra import Model, Reaction, Metabolite
reaction = Reaction('PBHB_EX')  
reaction.name = 'PBHB_EX'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default
iMsOB3b.add_reaction(reaction)
iMsOB3b.reactions.PBHB_EX.reaction = 'pbhb_c => ' 

iMsOB3b.reactions.EX_ch4_e.bounds = (-100, 0)  ## 메탄 uptake rates
iMsOB3b.reactions.FALDA.bounds = (0, 0)         ## THF 관련 유전자
iMsOB3b.reactions.EX_nh4_e.bounds = (0, 0)      ## 암모니아 바운드 0
iMsOB3b.reactions.EX_n2_e.bounds = (0, 0)       ## 질소 바운드 0
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)  ## 질산 바운드 -inf ## 과제팀은 이거씀

iMsOB3b.reactions.PHBD2.bounds = (0, 0) ## pbhb_c 분해 경로 제거

iMsOB3b.reactions.Biomass_Mextorquens_AM1_core.bounds = (0, 0) ## Biomass 0

iMsOB3b.objective = 'PBHB_EX'
############################################################################

loop_sol = iMsOB3b.optimize()

## Loopless FBA flux값 저장 ###
model_flux(iMsOB3b, loop_sol)

loop_sol.fluxes.to_csv('Loop_FBA_result.json')

# %%
## Moma 설정 ## #####
## https://cobrapy.readthedocs.io/en/0.17.1/autoapi/cobra/flux_analysis/moma/index.html ##
#sol_moma = cobra.flux_analysis.moma(iMsOB3b)
#model_flux(iMsOB3b,sol_moma )

# %%
## Essential_genes 찾기 ##

# Ojective Function 하고 싶은거 설정 #

## Json 모델 불러오기 ##
model_dir = r'/content/gem_methylosinus_trichosporium/model_files/iMsOB3b.json'
iMsOB3b = cobra.io.load_json_model(model_dir)

reaction = Reaction('PBHB_EX')  
reaction.name = 'PBHB_EX'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default
iMsOB3b.add_reaction(reaction)
iMsOB3b.reactions.PBHB_EX.reaction = 'pbhb_c => ' 
iMsOB3b.reactions.EX_ch4_e.bounds = (-100, 0)  ## 메탄 uptake rates
iMsOB3b.reactions.FALDA.bounds = (0, 0)         ## THF 관련 유전자
iMsOB3b.reactions.EX_nh4_e.bounds = (0, 0)      ## 암모니아 바운드 0
iMsOB3b.reactions.EX_n2_e.bounds = (0, 0)       ## 질소 바운드 0
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)  ## 질산 바운드 -inf ## 과제팀은 이거씀
iMsOB3b.reactions.PHBD2.bounds = (0, 0) ## pbhb_c 분해 경로 제거

## Objective 설정 ##
iMsOB3b.objective = 'Biomass_Mextorquens_AM1_core'

##  Essential Gene 확인 ##
essen_gene_list = cobra.flux_analysis.find_essential_genes(iMsOB3b)
essen_gene_list
print('Essential Gene Counts :', len(essen_gene_list))
## Essential Reaction 확인 ##

essen_rxn_list = cobra.flux_analysis.find_essential_reactions(iMsOB3b)
print('Essential Rxn Counts :',len(essen_rxn_list))
#essen_gene_list
# Out:
# Essential Gene Counts : 334
# Essential Rxn Counts : 530

# %%
### single gene deletion 분석 ##
### Ref) https://cobrapy.readthedocs.io/en/0.17.1/autoapi/cobra/flux_analysis/moma/index.html
### 칼럼에 Growth라 써있지만 Objective의 Flux값을 의미하는 것으로 예상됨 - 아래 결과에서 PHAS 최대 Flux인 0.0340 값 확인 ###
iMsOB3b.objective = 'PHAS'
single_deletion = cobra.flux_analysis.deletion.single_reaction_deletion(iMsOB3b,
                                                      method = 'fba',
                                                      solution = 'moma',
                                                      )
# Out:
#                  growth   status
# ids
# (MTHFD)    2.430171e-17  optimal
# (UAGCVT)   0.000000e+00  optimal
# (UAMAGS)   0.000000e+00  optimal
# (HACD7)    3.400784e-02  optimal
# (PAPPT3)   0.000000e+00  optimal
# ...                 ...      ...
# (CH4trpp)  3.400784e-02  optimal
# (HACD1)    3.400784e-02  optimal
# (PPND)     4.070938e-17  optimal
# (PMDPHT)   7.641700e-17  optimal
# (CLtex)   -6.393119e-17  optimal
#
# [1041 rows x 2 columns]

# %%
### single gene deletion 분석 ## V2
### Ref) https://cobrapy.readthedocs.io/en/0.17.1/autoapi/cobra/flux_analysis/index.html?highlight=single_reaction_deletion#cobra.flux_analysis.single_reaction_deletion
### 칼럼에 Growth라 써있지만 Objective의 Flux값을 의미하는 것으로 예상됨 - 아래 결과에서 PHAS 최대 Flux인 0.0340 값 확인 ###
model_dir = r'/content/gem_methylosinus_trichosporium/model_files/iMsOB3b.json'
iMsOB3b = cobra.io.load_json_model(model_dir)

reaction = Reaction('PBHB_EX')  
reaction.name = 'PBHB_EX'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default
iMsOB3b.add_reaction(reaction)
iMsOB3b.reactions.PBHB_EX.reaction = 'pbhb_c => ' 
iMsOB3b.reactions.EX_ch4_e.bounds = (-100, 0)  ## 메탄 uptake rates
iMsOB3b.reactions.FALDA.bounds = (0, 0)         ## THF 관련 유전자
iMsOB3b.reactions.EX_nh4_e.bounds = (0, 0)      ## 암모니아 바운드 0
iMsOB3b.reactions.EX_n2_e.bounds = (0, 0)       ## 질소 바운드 0
iMsOB3b.reactions.EX_no3_e.bounds = (-1000, 0)  ## 질산 바운드 -inf ## 과제팀은 이거씀
iMsOB3b.reactions.PHBD2.bounds = (0, 0) ## pbhb_c 분해 경로 제거


iMsOB3b.objective = 'Biomass_Mextorquens_AM1_core'
single_deletion = cobra.flux_analysis.single_gene_deletion(iMsOB3b,
                                                      method = 'pfba',
                                                      #solution = 'moma',
                                                      )

# %%
single_deletion.loc[(single_deletion['growth']<=0.01)|(single_deletion['status']=='infeasible')]
#single_deletion.to_csv('single_deletion_Biomass.csv')
# Out:
#                      growth      status
# ids
# (CQW49_20395)  0.000000e+00     optimal
# (CQW49_09060) -1.535063e-15     optimal
# (CQW49_01070)  1.279219e-15     optimal
# (CQW49_11235)  7.945256e-32     optimal
# (CQW49_10320)  7.945256e-32     optimal
# ...                     ...         ...
# (CQW49_18385)  4.687972e-15     optimal
# (CQW49_02440)  2.120722e-17     optimal
# (CQW49_03825)           NaN  infeasible
# (CQW49_01845)  1.384871e-17     optimal
# (CQW49_14270)  1.384871e-17     optimal
#
# [334 rows x 2 columns]

# %%
### Robust Analysis?? ###
results_rb = cobra.flux_analysis.phenotype_phase_plane.production_envelope(iMsOB3b, 
                                                              reactions =['Biomass_Mextorquens_AM1_core' ,'PPND'], 
                                                              objective = 'PHAS',
                                                              carbon_sources = 'EX_ch4_e', 
                                                              points = 20)
results_rb
# Out:
#     carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0        EX_ch4_e      0.000000                   0.0                 NaN
# 1        EX_ch4_e           NaN                   NaN                 NaN
# 2        EX_ch4_e           NaN                   NaN                 NaN
# 3        EX_ch4_e           NaN                   NaN                 NaN
# 4        EX_ch4_e           NaN                   NaN                 NaN
# ..            ...           ...                   ...                 ...
# 395      EX_ch4_e           NaN                   NaN                 NaN
# 396      EX_ch4_e           NaN                   NaN                 NaN
# 397      EX_ch4_e           NaN                   NaN                 NaN
# 398      EX_ch4_e           NaN                   NaN                 NaN
# 399      EX_ch4_e      0.034008                   0.0                 NaN
#
#      flux_maximum  carbon_yield_maximum  mass_yield_maximum  \
# 0        0.000000                   0.0                 NaN
# 1             NaN                   NaN                 NaN
# 2             NaN                   NaN                 NaN
# 3             NaN                   NaN                 NaN
# 4             NaN                   NaN                 NaN
# ..            ...                   ...                 ...
# 395           NaN                   NaN                 NaN
# 396           NaN                   NaN                 NaN
# 397           NaN                   NaN                 NaN
# 398           NaN                   NaN                 NaN
# 399      0.034008                   0.0                 NaN
#
#      Biomass_Mextorquens_AM1_core      PPND
# 0                        0.000000  0.000000
# 1                        0.000000  0.000489
# 2                        0.000000  0.000977
# 3                        0.000000  0.001466
# 4                        0.000000  0.001954
# ..                            ...       ...
# 395                      0.122604  0.007328
# 396                      0.122604  0.007816
# 397                      0.122604  0.008305
# 398                      0.122604  0.008793
# 399                      0.122604  0.009282
#
# [400 rows x 9 columns]

# %%
## optgene, optknock 돌리기 위한 Tool 설치##
# !pip install cameo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cameo
#   Downloading cameo-0.13.6-py2.py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 5.2 MB/s
# Collecting escher>=1.1.2
#   Downloading Escher-1.7.3-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 38.4 MB/s
# Requirement already satisfied: cobra>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from cameo) (0.17.0)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from cameo) (2.23.0)
# Collecting gnomic==1.0.1
#   Downloading gnomic-1.0.1.tar.gz (13 kB)
# Requirement already satisfied: pandas>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from cameo) (1.3.5)
# Requirement already satisfied: palettable>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from cameo) (3.3.0)
# Collecting blessings>=1.5.1
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: optlang>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from cameo) (1.5.2)
# Requirement already satisfied: numexpr>=2.4 in /usr/local/lib/python3.7/dist-packages (from cameo) (2.8.1)
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.7/dist-packages (from cameo) (7.1.2)
# Collecting IProgress>=0.4
#   Downloading IProgress-0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from cameo) (1.4.1)
# Collecting inspyred>=1.0
#   Downloading inspyred-1.0.1-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 7.1 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from cameo) (1.21.6)
# Collecting ordered-set>=1.2
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from cameo) (0.16.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.7/dist-packages (from cameo) (2.6.3)
# Requirement already satisfied: openpyxl>=2.4.5 in /usr/local/lib/python3.7/dist-packages (from cameo) (3.0.10)
# Collecting lazy-object-proxy>=1.2.0
#   Downloading lazy_object_proxy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.2 MB/s
# Collecting grako==3.18.1
#   Downloading grako-3.18.1-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 4.9 MB/s
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from gnomic==1.0.1->cameo) (1.15.0)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.7/dist-packages (from cobra>=0.11.1->cameo) (5.0.5)
# Requirement already satisfied: ruamel.yaml>=0.16 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.11.1->cameo) (0.17.21)
# Requirement already satisfied: python-libsbml-experimental==5.18.0 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.11.1->cameo) (5.18.0)
# Requirement already satisfied: depinfo in /usr/local/lib/python3.7/dist-packages (from cobra>=0.11.1->cameo) (2.1.1)
# Collecting jsonschema<4,>=3.0.1
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.7 MB/s
# Collecting pytest<5,>=4.0.1
#   Downloading pytest-4.6.11-py2.py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 37.9 MB/s
# Requirement already satisfied: Jinja2<3,>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from escher>=1.1.2->cameo) (2.11.3)
# Requirement already satisfied: ipywidgets<8,>=7.4.0 in /usr/local/lib/python3.7/dist-packages (from escher>=1.1.2->cameo) (7.7.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.10.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.1.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (2.6.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3,>=2.7.3->escher>=1.1.2->cameo) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (4.11.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (0.18.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.10.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (2.15.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr>=2.4->cameo) (21.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.4.5->cameo) (1.1.0)
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang>=1.4.2->cameo) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.3->cameo) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.3->cameo) (2022.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.2.5)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (8.13.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (1.4.0)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->cameo) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->cameo) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->cameo) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->cameo) (3.0.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml>=0.16->cobra>=0.11.1->cameo) (0.2.6)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang>=1.4.2->cameo) (1.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.13.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (23.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr>=2.4->cameo) (3.0.9)
# Building wheels for collected packages: gnomic
#   Building wheel for gnomic (setup.py) ... done
#   Created wheel for gnomic: filename=gnomic-1.0.1-py3-none-any.whl size=14671 sha256=0cb2ff8a3fa5eaa89c05d483de64e0b90827c6acdc00d71fe001b9757f49d5ce
#   Stored in directory: /root/.cache/pip/wheels/78/c5/31/10f917cc1ca63da8ca323fb2f79aa37d0cc75211561beb9d4c
# Successfully built gnomic
# Installing collected packages: jsonschema, pluggy, pytest, grako, ordered-set, lazy-object-proxy, IProgress, inspyred, gnomic, escher, blessings, cameo
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclient 0.6.4 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# nbclient 0.6.4 requires traitlets>=5.2.2, but you have traitlets 5.1.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed IProgress-0.4 blessings-1.7 cameo-0.13.6 escher-1.7.3 gnomic-1.0.1 grako-3.18.1 inspyred-1.0.1 jsonschema-3.2.0 lazy-object-proxy-1.7.1 ordered-set-4.1.0 pluggy-0.13.1 pytest-4.6.11

# %%
## Optgene ## A Methond using evolutionary algorithms
from cameo.strain_design import OptGene
optgene = OptGene(iMsOB3b)

result = optgene.run(target=iMsOB3b.reactions.PHAS,
                     biomass=iMsOB3b.reactions.Biomass_Mextorquens_AM1_core,
                     substrate=iMsOB3b.metabolites.ch4_e, ## EX_ch4_e ###
                     max_evaluations=5000,
                     plot=False)
result
# Out:
# Starting optimization at Thu, 09 Jun 2022 18:10:09
# HBox()
# Finished after 00:04:54
# No solutions found
#         <h3>OptGene Result</h3>
#         <ul>
#             <li>Simulation: fba<br/></li>
#             <li>Objective Function: $$bpcy = \frac{(Biomass\_Mextorquens\_AM1\_core * PHAS)}{EX\_ch4\_e}$$<br/></li>
#         </ul>
#         <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>reactions</th>
#       <th>genes</th>
#       <th>size</th>
#       <th>fva_min</th>
#       <th>fva_max</th>
#       <th>target_flux</th>
#       <th>biomass_flux</th>
#       <th>yield</th>
#       <th>fitness</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
## OptKnock ## A method using linear programming ###
from cameo.strain_design import OptKnock
optknock = OptKnock(iMsOB3b, fraction_of_optimum=0.1)

result = optknock.run(max_knockouts=2,
                     target=iMsOB3b.reactions.PHAS,
                     biomass=iMsOB3b.reactions.Biomass_Mextorquens_AM1_core,
                    # substrate=iMsOB3b.metabolites.ch4_e, ## EX_ch4_e ###
                     #max_evaluations=5000,
                     #plot=False,
                      )
result
# Out:
# /usr/local/lib/python3.7/dist-packages/cameo/strain_design/deterministic/linear_programming.py:119 UserWarning: You are trying to run OptKnock with glpk_interface. This might not end well.
# HBox()
#         <h3>OptKnock:</h3>
#         <ul>
#             <li>Target: PHAS</li>
#         </ul>
#         <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>reactions</th>
#       <th>size</th>
#       <th>PHAS</th>
#       <th>biomass</th>
#       <th>fva_min</th>
#       <th>fva_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>{NTPP7, CYOD}</td>
#       <td>2</td>
#       <td>0.034008</td>
#       <td>0.122604</td>
#       <td>0.033668</td>
#       <td>0.034008</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
############# 기본 입력 방식 ####################
## 특정 반응식(PPND) 확인
# iMsOB3b.reactions.PPND.reaction

## 특정 반응식(PPND) 변경
# iMsOB3b.reactions.PPND.reaction = "ch4_p + o2_p + qh2_c --> h2o_p + meoh_p + q_c"
## 처음 넣는 대사체로 변경할 경우, unknown metabolite "xx" created 라는 말이 뜬다

## 특정 대사물질(q_c)이 포함된 반응식을 모두 뽑아내는 방법 ###
# for reaction in iMsOB3b.metabolites.q_c.reactions:
#     print(reaction.name, reaction)

## 반응식에 대사체 추가하기 ##
# iMsOB3b.reactions.PPND.add_metabolites({model.metabolites.get_by_id("h_c"): -1})
# iMsOB3b.reactions.PPND.reaction


## bound 확인##
# iMsOB3b.reactions.PGI.lower_bound,  iMsOB3b.reactions.PGI.upper_bound
## bound 변경##
# pgi.bounds = (0, 1000.0)

## deletion 처리할때
# AM1_bigg.reactions.PMMODCipp.knock_out()


## 특정 Reaction 뽑아낼 때, list comprehension 사용 ##
# qh2_c_consuming = [rxn for rxn in model_OB3b.metabolites.qh2_c.reactions if rxn.reversibility or model_OB3b.metabolites.qh2_c in rxn.reactants]

## 모델 Reaction에서 특정 단어가 들어간걸 찾을 떄 쓰는 방식.. ##
# import re
# for reaction in iMsOB3b.reactions:
#     if re.search("translocatin", reaction.name, re.IGNORECASE):
#         print(reaction.id, reaction.name)
# Out:
# NADH ubiquinone oxidoreductase I NADH11: 5.0 h_c + nadh_c + q_c --> 4.0 h_p + nad_c + qh2_c
# succinate dehydrogenase SUCCD1: q_c + succ_c <=> fum_c + qh2_c
# QRr QRr: h_c + nadph_c + q_c --> nadp_c + qh2_c
# Nitrate reductase (Ubiquinol-8) NO3R1: no3_c + qh2_c --> h2o_c + no2_c + q_c
# ETF dehydrogenase ETFDH: q_c + rETF_c <=> oxETF_c + qh2_c
# particulate Methane Monooxygenase PMMOipp: ch4_p + o2_p + qh2_c --> h2o_p + meoh_p + q_c
# particulate ammonia monooxygenase PAMMOipp: nh4_p + o2_p + qh2_c --> h2o_p + h_p + ham_p + q_c
# ubiquinol cytochrome c reductase UQCYOR_2p: 2.0 ficytc_c + qh2_c --> 2.0 focytc_c + 2.0 h_p + q_c
# cytochrome bd ubiquinol oxidase CYOD: 4.0 h_c + o2_c + 2.0 qh2_c --> 2.0 h2o_c + 4.0 h_p + 2.0 q_c
# cytochrome o ubiquinol oxidase CYOO_4p: 4.0 h_c + 0.5 o2_c + qh2_c --> h2o_c + 4.0 h_p + q_c
# photosystem I cyclic PHOTOSYS1C: 2.0 fdxrd_c + 2.0 h_c + q_c --> 2.0 fdxox_c + qh2_c
# NADPH Quinone Reductase (Ubiquinone-8) NADPHQR2: h_c + nadph_c + q_c --> nadp_c + qh2_c
# (-1000.0, 1000.0)

# %%
## 모델에 새로운 Reaction 추가하기 ##
#####
# Step 1) 타? 모델에 있는 rxn을 가져오기...?
# iMsOB3b_adapted_reactions = [iMsOB3b.reactions.SAMMOi, iMsOB3b.reactions.NO3t7pp, iMsOB3b.reactions.NO3R1, 
#                              iMsOB3b.reactions.NITR_NOpp, iMsOB3b.reactions.NITR_AMpp, 
#                              iMsOB3b.reactions.NTRIR2y, iMsOB3b.reactions.NTRIR2x]

# Step 2) 쓸 모델에 add하기...  add_reaction은  Cobra.core.reaction인가? 이 포멧만 넣을 수 있음.. (출처 논문..)
# for reaction in iMsOB3b_adapted_reactions:
#     model_OB3b.add_reaction(reaction)
    
# Step 3) 그리고 reaction 식 바꾸기.. 아래처럼..
# model_OB3b.reactions.SAMMOi.reaction = "ch4_p + o2_p + qh2_c --> h2o_p + meoh_p + q_c"

# %%
## 원랜 신규 Reaciton 만드는 방법은 아래와 같다.... 복잡... ##
from cobra import Model, Reaction, Metabolite

reaction = Reaction('R_3OAS140')
reaction.name = '3 oxoacyl acyl carrier protein synthase n C140 '
reaction.subsystem = 'Cell Envelope Biosynthesis'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default

ACP_c = Metabolite(
    'ACP_c',
    formula='C11H21N2O7PRS',
    name='acyl-carrier-protein',
    compartment='c')
omrsACP_c = Metabolite(
    'M3omrsACP_c',
    formula='C25H45N2O9PRS',
    name='3-Oxotetradecanoyl-acyl-carrier-protein',
    compartment='c')
co2_c = Metabolite('co2_c', formula='CO2', name='CO2', compartment='c')
malACP_c = Metabolite(
    'malACP_c',
    formula='C14H22N2O10PRS',
    name='Malonyl-acyl-carrier-protein',
    compartment='c')
h_c = Metabolite('h_c', formula='H', name='H', compartment='c')
ddcaACP_c = Metabolite(
    'ddcaACP_c',
    formula='C23H43N2O8PRS',
    name='Dodecanoyl-ACP-n-C120ACP',
    compartment='c')



reaction.add_metabolites({
    malACP_c: -1.0,
    h_c: -1.0,
    ddcaACP_c: -1.0,
    co2_c: 1.0,
    ACP_c: 1.0,
    omrsACP_c: 1.0
})


reaction.gene_reaction_rule = '( STM2378 or STM1197 )'


### 간단 추가 버전 ##
from cobra import Model, Reaction, Metabolite
# Best practise: SBML compliant IDs

reaction = Reaction('PFK')
reaction.name = 'Phosphofructokinase'
reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default

iMsOB3b.add_reaction(reaction)
iMsOB3b.reactions.PFK.reaction = 'atp_c + f6p_c <=> adp_c + fdp_c + h_c'
iMsOB3b.reactions.FDHr.gene_reaction_rule = 'CQW49_16615 and CQW49_16630 and (CQW49_16625 or CQW49_16125) and CQW49_16635'

# %%
### KEGG 적용 ###
import orangecontrib.bioinformatics.kegg

organism = orangecontrib.bioinformatics.kegg.Organism("Methylosinus trichosporium")
genes = organism.genes
gene_entry = genes["CQW49_13850"]
print(gene_entry.entry, gene_entry.definition)

organism = orangecontrib.bioinformatics.kegg.Organism("Methylosinus trichosporium")
genes = organism.genes
gene_entry = genes["CQW49_12210"]
print(gene_entry.entry, gene_entry.orthology)


organism = orangecontrib.bioinformatics.kegg.Organism("Methylosinus trichosporium")
genes = organism.genes
gene_entry = genes["CQW49_04750"]
print(gene_entry.entry, gene_entry.definition, gene_entry.orthology)


enzyme=orangecontrib.bioinformatics.kegg.databases.Enzyme()
enzyme_entry = enzyme["ec:2.3.3.1"]
print(enzyme_entry.reaction)

# %%
#script for renaming record description in Refseq or Genbank files

#importing Biopythom SeqIO library
from Bio import SeqIO

#loading multiple gene elements from a fasta file
records = list(SeqIO.parse(fastas_directory + "OB3b/New_2017_assembly/GenBank_ASM275265v1_translated_cds.faa", 
                           "fasta"))


## 이렇게 가져와서, 기존 모델을 바꿔서 GEM 모델을 만들기도..

# %%
# !pip install escher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: escher in /usr/local/lib/python3.7/dist-packages (1.7.3)
# Requirement already satisfied: pytest<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from escher) (4.6.11)
# Requirement already satisfied: Jinja2<3,>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from escher) (2.11.3)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from escher) (3.2.0)
# Requirement already satisfied: cobra>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from escher) (0.17.0)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from escher) (1.3.5)
# Requirement already satisfied: ipywidgets<8,>=7.4.0 in /usr/local/lib/python3.7/dist-packages (from escher) (7.7.0)
# Requirement already satisfied: depinfo in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (2.1.1)
# Requirement already satisfied: optlang>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (1.5.2)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (1.15.0)
# Requirement already satisfied: ruamel.yaml>=0.16 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (0.17.21)
# Requirement already satisfied: python-libsbml-experimental==5.18.0 in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (5.18.0)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (5.0.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from cobra>=0.5.0->escher) (0.16.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (1.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (5.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (4.10.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.4.0->escher) (3.6.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher) (5.3.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (57.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3,>=2.7.3->escher) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher) (4.11.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->escher) (0.18.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher) (2.15.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher) (4.10.0)
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang>=1.4.2->cobra>=0.5.0->escher) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->escher) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->escher) (2022.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher) (0.2.5)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher) (21.3)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher) (8.13.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest<5,>=4.0.1->escher) (0.13.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4,>=3.0.1->escher) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4,>=3.0.1->escher) (3.8.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml>=0.16->cobra>=0.5.0->escher) (0.2.6)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang>=1.4.2->cobra>=0.5.0->escher) (1.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (5.6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher) (23.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.7.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.4.0->escher) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest<5,>=4.0.1->escher) (3.0.9)

# %%
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: /usr/local/etc/jupyter/nbconfig
#     notebook section
#       escher/extension  enabled
#       - Validating: OK
#       jupyterlab-plotly/extension  enabled
#       - Validating: OK
#       jupyter-js-widgets/extension  enabled
#       - Validating: OK

# %%
from re import template
import escher
from escher import Builder
from time import sleep
#from google.colab import output
#output.enable_custom_widget_manager()
builder = Builder(
    height = 50,
    model_json = r'/content/gem_methylosinus_trichosporium/model_files/iMsOB3b.json',
    map_json = r'/content/gem_methylosinus_trichosporium/escher_metabolic_map/Methylosinus_trichosporium_OB3b_map.json')
builder.reaction_data = FBA_sol.fluxes
builder.reaction_scale_preset = 'GaBuRd'
builder.reaction_scale = [
        { 'type' : 'value', 'value': -10, 'color': '#ef2929', 'size': 20 },
        { 'type' : 'value', 'value': 0, 'color': '#729fcf', 'size': 20 },
        { 'type' : 'value', 'value': +10, 'color': '#4e9a06', 'size': 20 }
    ]
# builder   ## 원랜 이거로 키는 거지만.... colab에서는 안됨.. 

from IPython.core.display import display, HTML
builder.save_html('map')
display(HTML('map'))
## https://escher.readthedocs.io/en/latest/escher-python.html
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Escher Builder</title>
#
#     <script src="https://unpkg.com/escher@1.7.3/dist/escher.min.js"></script>
#
#     <meta charset="utf-8"/>
#     <meta name="viewport" content="width=device-width, height=device-height,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no, minimal-ui"/>
#   </head>
#   <body>
#     <div style="height: 100%; width: 100%;" id="map-container"></div>
#
#     <script>
#      /* Data from python */
#      var data = get_data();
#      escher.Builder(data.map_data, data.model_data, data.embedded_css,
#                     escher.libs.d3_select('#map-container'), data.options);
#
#      function b64DecodeUnicode(str) {
#        return decodeURIComponent(Array.prototype.map.call(atob(str), function(c) {
#          return '%' + ('00' + c.charCodeAt(0).toString(16)).slice(-2)
#        }).join(''))
#      }
#
#      // Put this at the end so Chrome doesn't cut off the code above.
#      function get_data() {
#        /** Return the data passed in by the Python module. */
#        const data = {
#          // defaults
#          map_data: null,
#          model_data: null,
#          embedded_css: null,
#          options: {
#            fill_screen: true,
#          }
#        };
#
#        data.map_data = JSON.parse(b64DecodeUnicode('...'));
#
#
#        data.model_data = JSON.parse(b64DecodeUnicode('...'));
#
#
#
#        const newOptions = JSON.parse(b64DecodeUnicode('...'));
#        data.options = Object.assign({}, data.options, newOptions);
#
#        return data;
#      }
#     </script>
#   </body>
# </html>
